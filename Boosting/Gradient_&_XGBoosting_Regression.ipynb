# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn import datasets, linear_model, metrics 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split 
import seaborn as sns
import statsmodels
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df=pd.read_excel('Data_Train.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source  ... Total_Stops Additional_Info  Price
# 0       IndiGo      24/03/2019  Banglore  ...    non-stop         No info   3897
# 1    Air India       1/05/2019   Kolkata  ...     2 stops         No info   7662
# 2  Jet Airways       9/06/2019     Delhi  ...     2 stops         No info  13882
# 3       IndiGo      12/05/2019   Kolkata  ...      1 stop         No info   6218
# 4       IndiGo      01/03/2019  Banglore  ...      1 stop         No info  13302
#
# [5 rows x 11 columns]

# %% [markdown]
# # Checking Unique Values

# %%
df.Airline.unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
df.Source.unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df.Destination.unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
df.Additional_Info.unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %% [markdown]
# # Data Cleaning

# %%
df.Additional_Info=df.Additional_Info.replace('No Info','No info')

# %%
df.drop(columns=['Route'],inplace=True)

# %%
df.drop(columns=['Dep_Time','Arrival_Time'],inplace=True)

# %%
#df.drop(columns=['Date_of_Journey'],inplace=True)

# %%
df.Destination.replace('New Delhi','Delhi',inplace=True)

# %%
df.replace('Delhi',1,inplace=True)
df.replace('Banglore',2,inplace=True)
df.replace('Cochin',3,inplace=True)
df.replace('Kolkata',4,inplace=True)
df.replace('Hyderabad',5,inplace=True)
df.replace('Chennai',6,inplace=True)
df.replace('Hyderabad',7,inplace=True)

# %%
df.replace('Mumbai',8,inplace=True)

# %%
df.Destination.unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df.Source.unique()
# Out:
# array([2, 4, 1, 6, 8])

# %%
df.Total_Stops.isnull().sum()
# Out:
# 1

# %%
df.dropna(inplace=True)

# %%
df.Total_Stops.replace('non-stop','0 stop',inplace=True)

# %%
df.Total_Stops=df.Total_Stops.apply(lambda x: int(x.split(' ')[0]))

# %% [markdown]
# # Creating Dummy Variables

# %%
df = pd.get_dummies(df, columns=['Total_Stops'],drop_first=True)
#TS_dummy=pd.get_dummies(df.Total_Stops,prefix="Total_Stops")
#TS_dummy

# %%
df = pd.get_dummies(df, columns=['Source'],drop_first=True)
df = pd.get_dummies(df, columns=['Destination'],drop_first=True)

# %%
df = pd.get_dummies(df, columns=['Additional_Info'],drop_first=True)

# %%
h = df['Duration'].str.extract('(\d+)h', expand=False).astype(float) * 60
m = df['Duration'].str.extract('(\d+)m', expand=False).astype(float)
df['Duration'] = h.add(m, fill_value=0).astype(int)

# %%
df.Duration=df.Duration.astype(float)

# %%
df.Price=df.Price.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10682 entries, 0 to 10682
# Data columns (total 24 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Airline                                       10682 non-null  object
#  1   Date_of_Journey                               10682 non-null  object
#  2   Duration                                      10682 non-null  float64
#  3   Price                                         10682 non-null  float64
#  4   Total_Stops_1                                 10682 non-null  uint8
#  5   Total_Stops_2                                 10682 non-null  uint8
#  6   Total_Stops_3                                 10682 non-null  uint8
#  7   Total_Stops_4                                 10682 non-null  uint8
#  8   Source_2                                      10682 non-null  uint8
#  9   Source_4                                      10682 non-null  uint8
#  10  Source_6                                      10682 non-null  uint8
#  11  Source_8                                      10682 non-null  uint8
#  12  Destination_2                                 10682 non-null  uint8
#  13  Destination_3                                 10682 non-null  uint8
#  14  Destination_4                                 10682 non-null  uint8
#  15  Destination_5                                 10682 non-null  uint8
#  16  Additional_Info_1 Short layover               10682 non-null  uint8
#  17  Additional_Info_2 Long layover                10682 non-null  uint8
#  18  Additional_Info_Business class                10682 non-null  uint8
#  19  Additional_Info_Change airports               10682 non-null  uint8
#  20  Additional_Info_In-flight meal not included   10682 non-null  uint8
#  21  Additional_Info_No check-in baggage included  10682 non-null  uint8
#  22  Additional_Info_No info                       10682 non-null  uint8
#  23  Additional_Info_Red-eye flight                10682 non-null  uint8
# dtypes: float64(2), object(2), uint8(20)
# memory usage: 625.9+ KB

# %%
df.Date_of_Journey=df.Date_of_Journey.astype('datetime64[ns]')

# %%
df
# Out:
#            Airline  ... Additional_Info_Red-eye flight
# 0           IndiGo  ...                              0
# 1        Air India  ...                              0
# 2      Jet Airways  ...                              0
# 3           IndiGo  ...                              0
# 4           IndiGo  ...                              0
# ...            ...  ...                            ...
# 10678     Air Asia  ...                              0
# 10679    Air India  ...                              0
# 10680  Jet Airways  ...                              0
# 10681      Vistara  ...                              0
# 10682    Air India  ...                              0
#
# [10682 rows x 24 columns]

# %%
plt.figure(figsize= (16,9))
sns.regplot(x ="Duration", y ="Price",data = df)

# %%
#plt.figure(figsize= (16,9))
#sns.regplot(x ="Total_Stops", y ="Price",data = df)

# %%
#df.Duration.values.reshape(-1,1)
#df.Price.values.reshape(-1,1)

# %%
#plt.bar(df.Additional_Info,df.Price)
#plt.xticks(rotation=90)
#plt.show()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),cmap=plt.cm.Reds,annot=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10682 entries, 0 to 10682
# Data columns (total 24 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Airline                                       10682 non-null  object
#  1   Date_of_Journey                               10682 non-null  datetime64[ns]
#  2   Duration                                      10682 non-null  float64
#  3   Price                                         10682 non-null  float64
#  4   Total_Stops_1                                 10682 non-null  uint8
#  5   Total_Stops_2                                 10682 non-null  uint8
#  6   Total_Stops_3                                 10682 non-null  uint8
#  7   Total_Stops_4                                 10682 non-null  uint8
#  8   Source_2                                      10682 non-null  uint8
#  9   Source_4                                      10682 non-null  uint8
#  10  Source_6                                      10682 non-null  uint8
#  11  Source_8                                      10682 non-null  uint8
#  12  Destination_2                                 10682 non-null  uint8
#  13  Destination_3                                 10682 non-null  uint8
#  14  Destination_4                                 10682 non-null  uint8
#  15  Destination_5                                 10682 non-null  uint8
#  16  Additional_Info_1 Short layover               10682 non-null  uint8
#  17  Additional_Info_2 Long layover                10682 non-null  uint8
#  18  Additional_Info_Business class                10682 non-null  uint8
#  19  Additional_Info_Change airports               10682 non-null  uint8
#  20  Additional_Info_In-flight meal not included   10682 non-null  uint8
#  21  Additional_Info_No check-in baggage included  10682 non-null  uint8
#  22  Additional_Info_No info                       10682 non-null  uint8
#  23  Additional_Info_Red-eye flight                10682 non-null  uint8
# dtypes: datetime64[ns](1), float64(2), object(1), uint8(20)
# memory usage: 625.9+ KB

# %% [markdown]
# # Feature Selection

# %%
df = pd.get_dummies(df, columns=['Airline'],drop_first=True)

# %%
X=df
X = X.drop(["Price","Date_of_Journey"],1)
X
#,19,20,21,22,23,24,25,26,27
# Out:
#        Duration  ...  Airline_Vistara Premium economy
# 0         170.0  ...                                0
# 1         445.0  ...                                0
# 2        1140.0  ...                                0
# 3         325.0  ...                                0
# 4         285.0  ...                                0
# ...         ...  ...                              ...
# 10678     150.0  ...                                0
# 10679     155.0  ...                                0
# 10680     180.0  ...                                0
# 10681     160.0  ...                                0
# 10682     500.0  ...                                0
#
# [10682 rows x 32 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
y = np.log(df.Price)
y
# Out:
# 0        8.267962
# 1        8.944028
# 2        9.538348
# 3        8.735204
# 4        9.495670
#            ...
# 10678    8.320448
# 10679    8.329658
# 10680    8.885856
# 10681    9.445254
# 10682    9.371864
# Name: Price, Length: 10682, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(n_estimators = 200, max_depth = 1, random_state = 1)

# %%
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=1,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=200,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
pred_y = gbr.predict(X_test)
pred_y
# Out:
# array([9.17452895, 9.22187912, 9.61660538, ..., 8.9861677 , 9.50264998,
#        9.22187912])

# %%
from sklearn.metrics import mean_squared_error as MSE
test_rmse = MSE(y_test, pred_y) ** (1 / 2)
test_rmse
# Out:
# 0.25527428026207416

# %%
gbr.score(X_train, y_train)
# Out:
# 0.7351216443706916

# %%
gbr.score(X_test, y_test)
# Out:
# 0.7564918273342467

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, pred_y)
# Out:
# 0.7564918273342467

# %%
#Using grid search for finding best parameters
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeRegressor
params = {'learning_rate':[0.1,0.3,0.5,0.7,0.9], 
          "max_depth": [3,5,10],'n_estimators':[10,20,50,70,80,90,100]}
grid_search_cv = GridSearchCV(gbr, params, scoring="r2",verbose=1, cv=3)
grid_search_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 105 candidates, totalling 315 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 315 out of 315 | elapsed:  1.8min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=1,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=200,
#                                                  n_iter_no_change=None,
#                                                  presort='deprecated',
#                                                  random_state=1, subsample=1.0,
#                                                  tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.3, 0.5, 0.7, 0.9],
#                          'max_depth': [3, 5, 10],
#                          'n_estimators': [10, 20, 50, 70, 80, 90, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=1)

# %%
grid_search_cv.best_params_
# Out:
# {'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 70}

# %%
gbr = GradientBoostingRegressor(learning_rate=0.3,n_estimators = 70, max_depth = 5, random_state = 1)

# %%
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.3, loss='ls', max_depth=5,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=70,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
pred_y1 = gbr.predict(X_test)
pred_y1
# Out:
# array([9.05456487, 9.3207107 , 9.52075614, ..., 9.13362337, 9.53791457,
#        9.18816954])

# %%
gbr.score(X_train, y_train)
# Out:
# 0.8361853348596566

# %%
gbr.score(X_test, y_test)
# Out:
# 0.8235312202955641

# %%
r2_score(y_test, pred_y1)
# Out:
# 0.8235312202955642

# %% [markdown]
# # XGBoosting

# %%
from xgboost import XGBRegressor

# %%
xgb=XGBRegressor()

# %%
xgb.fit(X_train,y_train)
# Out:
# [08:56:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predict = xgb.predict(X_test)

# %%
xgb.score(X_train, y_train)
# Out:
# 0.7846627272594527

# %%
xgb.score(X_test, y_test)
# Out:
# 0.7938727901401534

# %%
r2_score(y_test, predict)
# Out:
# 0.7938727901401534

# %%
#Using grid search for finding best parameters
params={"learning_rate"    : [0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 2, 4, 6, 8, 10],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ] }
grid_search_cv = GridSearchCV(xgb, params, scoring="r2",verbose=3, cv=3)
grid_search_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 1600 candidates, totalling 4800 fits
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=1
# [09:11:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=1, score=0.741, total=   0.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=1
# [09:11:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=1, score=0.757, total=   0.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=1
# [09:11:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=1, score=0.755, total=   0.2s
# [CV] colsample_bytree=0.3, gamma=0.1, learning_rate=0.1, max_depth=2, min_child_weight=3
# [09:11:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# Streaming output truncated to the last 5000 lines.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, score=0.788, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1
# [09:31:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=1, score=0.778, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3
# [09:31:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3, score=0.773, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3
# [09:31:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3, score=0.787, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3
# [09:31:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=3, score=0.781, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5
# [09:31:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5, score=0.770, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5
# [09:31:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5, score=0.787, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5
# [09:31:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=5, score=0.781, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=7
# [09:31:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=7, score=0.767, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=7
# [09:31:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=7, score=0.786, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=7
# [09:31:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=4, min_child_weight=7, score=0.773, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1
# [09:31:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1, score=0.775, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1
# [09:31:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1, score=0.797, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1
# [09:31:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=1, score=0.787, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3
# [09:31:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3, score=0.777, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3
# [09:31:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3, score=0.798, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3
# [09:31:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=3, score=0.787, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5
# [09:31:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5, score=0.778, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5
# [09:31:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5, score=0.796, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5
# [09:31:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=5, score=0.786, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=7
# [09:31:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=7, score=0.777, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=7
# [09:31:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=7, score=0.795, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=7
# [09:31:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=6, min_child_weight=7, score=0.784, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1
# [09:31:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, score=0.780, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1
# [09:31:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, score=0.800, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1
# [09:31:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=1, score=0.795, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3
# [09:31:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3, score=0.780, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3
# [09:31:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3, score=0.800, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3
# [09:31:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3, score=0.796, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5
# [09:31:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, score=0.782, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5
# [09:31:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, score=0.799, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5
# [09:31:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=5, score=0.794, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=7
# [09:31:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=7, score=0.783, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=7
# [09:31:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=7, score=0.794, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=7
# [09:31:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=7, score=0.788, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=1
# [09:31:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=1, score=0.787, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=1
# [09:31:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=1, score=0.802, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=1
# [09:31:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=1, score=0.794, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=3
# [09:31:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=3, score=0.783, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=3
# [09:31:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=3, score=0.806, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=3
# [09:31:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=3, score=0.798, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=5
# [09:31:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=5, score=0.785, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=5
# [09:31:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=5, score=0.800, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=5
# [09:31:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=5, score=0.798, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=7
# [09:31:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=7, score=0.782, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=7
# [09:31:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=7, score=0.799, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=7
# [09:31:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.2, max_depth=10, min_child_weight=7, score=0.792, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=1
# [09:31:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=1, score=0.751, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=1
# [09:31:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=1, score=0.768, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=1
# [09:31:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=1, score=0.762, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=3
# [09:31:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=3, score=0.747, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=3
# [09:31:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=3, score=0.770, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=3
# [09:31:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=3, score=0.764, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=5
# [09:31:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=5, score=0.749, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=5
# [09:31:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=5, score=0.767, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=5
# [09:31:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=5, score=0.755, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=7
# [09:31:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=7, score=0.749, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=7
# [09:31:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=7, score=0.766, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=7
# [09:31:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=2, min_child_weight=7, score=0.758, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=1
# [09:31:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=1, score=0.766, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=1
# [09:31:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=1, score=0.786, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=1
# [09:31:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=1, score=0.779, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=3
# [09:31:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=3, score=0.767, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=3
# [09:31:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=3, score=0.790, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=3
# [09:31:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=3, score=0.781, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=5
# [09:31:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=5, score=0.770, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=5
# [09:31:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=5, score=0.786, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=5
# [09:31:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=5, score=0.781, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=7
# [09:31:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=7, score=0.768, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=7
# [09:31:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=7, score=0.788, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=7
# [09:31:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=4, min_child_weight=7, score=0.777, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=1
# [09:31:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=1, score=0.774, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=1
# [09:31:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=1, score=0.792, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=1
# [09:31:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=1, score=0.788, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=3
# [09:31:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=3, score=0.778, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=3
# [09:31:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=3, score=0.796, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=3
# [09:31:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=3, score=0.792, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=5
# [09:31:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=5, score=0.776, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=5
# [09:31:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=5, score=0.792, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=5
# [09:31:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=5, score=0.788, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=7
# [09:31:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=7, score=0.777, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=7
# [09:31:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=7, score=0.791, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=7
# [09:31:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=6, min_child_weight=7, score=0.784, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=1
# [09:31:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=1, score=0.780, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=1
# [09:32:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=1, score=0.804, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=1
# [09:32:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=1, score=0.794, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=3
# [09:32:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=3, score=0.780, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=3
# [09:32:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=3, score=0.801, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=3
# [09:32:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=3, score=0.795, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=5
# [09:32:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=5, score=0.780, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=5
# [09:32:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=5, score=0.799, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=5
# [09:32:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=5, score=0.792, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=7
# [09:32:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=7, score=0.779, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=7
# [09:32:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=7, score=0.795, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=7
# [09:32:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=8, min_child_weight=7, score=0.789, total=   0.6s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=1
# [09:32:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=1, score=0.786, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=1
# [09:32:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=1, score=0.802, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=1
# [09:32:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=1, score=0.798, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=3
# [09:32:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=3, score=0.783, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=3
# [09:32:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=3, score=0.803, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=3
# [09:32:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=3, score=0.796, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=5
# [09:32:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=5, score=0.784, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=5
# [09:32:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=5, score=0.801, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=5
# [09:32:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=5, score=0.796, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=7
# [09:32:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=7, score=0.783, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=7
# [09:32:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=7, score=0.796, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=7
# [09:32:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.25, max_depth=10, min_child_weight=7, score=0.792, total=   0.7s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=1
# [09:32:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=1, score=0.745, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=1
# [09:32:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=1, score=0.771, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=1
# [09:32:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=1, score=0.761, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=3
# [09:32:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=3, score=0.744, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=3
# [09:32:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=3, score=0.774, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=3
# [09:32:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=3, score=0.764, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=5
# [09:32:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=5, score=0.744, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=5
# [09:32:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=5, score=0.769, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=5
# [09:32:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=5, score=0.760, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=7
# [09:32:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=7, score=0.752, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=7
# [09:32:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=7, score=0.768, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=7
# [09:32:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=2, min_child_weight=7, score=0.759, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=1
# [09:32:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=1, score=0.772, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=1
# [09:32:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=1, score=0.786, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=1
# [09:32:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=1, score=0.782, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=3
# [09:32:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=3, score=0.768, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=3
# [09:32:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=3, score=0.793, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=3
# [09:32:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=3, score=0.785, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5
# [09:32:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, score=0.771, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5
# [09:32:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, score=0.784, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5
# [09:32:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=5, score=0.779, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=7
# [09:32:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=7, score=0.772, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=7
# [09:32:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=7, score=0.787, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=7
# [09:32:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=4, min_child_weight=7, score=0.780, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1
# [09:32:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, score=0.779, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1
# [09:32:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, score=0.797, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1
# [09:32:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=1, score=0.788, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=3
# [09:32:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=3, score=0.780, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=3
# [09:32:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=3, score=0.798, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=3
# [09:32:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=3, score=0.788, total=   0.4s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5
# [09:32:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5, score=0.775, total=   0.5s
# [CV] colsample_bytree=0.5, gamma=0.3, learning_rate=0.3, max_depth=6, min_child_weight=5
# [09:32:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=3
# [09:45:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=3, score=0.779, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=5
# [09:45:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=5, score=0.768, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=5
# [09:45:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=5, score=0.785, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=5
# [09:45:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=5, score=0.775, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=7
# [09:45:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=7, score=0.764, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=7
# [09:45:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=7, score=0.783, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=7
# [09:45:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=4, min_child_weight=7, score=0.775, total=   0.4s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=1
# [09:45:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=1, score=0.770, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=1
# [09:45:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=1, score=0.788, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=1
# [09:45:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=1, score=0.783, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3
# [09:45:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, score=0.777, total=   0.6s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3
# [09:45:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, score=0.795, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3
# [09:45:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=3, score=0.788, total=   0.6s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5
# [09:45:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, score=0.778, total=   0.6s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5
# [09:45:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, score=0.793, total=   0.6s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5
# [09:45:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=5, score=0.786, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=7
# [09:45:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=7, score=0.772, total=   0.6s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=7
# [09:45:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=7, score=0.791, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=7
# [09:45:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=6, min_child_weight=7, score=0.782, total=   0.5s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1
# [09:45:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, score=0.780, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1
# [09:45:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, score=0.795, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1
# [09:45:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=1, score=0.792, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=3
# [09:45:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=3, score=0.779, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=3
# [09:45:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=3, score=0.797, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=3
# [09:45:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=3, score=0.794, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=5
# [09:45:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=5, score=0.780, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=5
# [09:45:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=5, score=0.795, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=5
# [09:45:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=5, score=0.789, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=7
# [09:45:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=7, score=0.781, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=7
# [09:45:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=7, score=0.796, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=7
# [09:45:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=8, min_child_weight=7, score=0.789, total=   0.7s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=1
# [09:45:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=1, score=0.783, total=   0.9s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=1
# [09:45:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=1, score=0.798, total=   0.8s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=1
# [09:45:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=1, score=0.797, total=   0.8s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=3
# [09:45:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=3, score=0.780, total=   0.9s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=3
# [09:45:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=3, score=0.801, total=   0.9s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=3
# [09:45:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=3, score=0.793, total=   0.8s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=5
# [09:45:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=5, score=0.781, total=   0.9s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=5
# [09:46:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=5, score=0.797, total=   0.9s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=5
# [09:46:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=5, score=0.793, total=   0.9s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=7
# [09:46:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=7, score=0.783, total=   0.8s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=7
# [09:46:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=7, score=0.797, total=   0.8s
# [CV] colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=7
# [09:46:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  colsample_bytree=0.7, gamma=0.4, learning_rate=0.3, max_depth=10, min_child_weight=7, score=0.791, total=   0.8s
# [09:46:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 4800 out of 4800 | elapsed: 34.9min finished
# GridSearchCV(cv=3, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_...1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'colsample_bytree': [0.3, 0.4, 0.5, 0.7],
#                          'gamma': [0.1, 0.2, 0.3, 0.4],
#                          'learning_rate': [0.1, 0.15, 0.2, 0.25, 0.3],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'min_child_weight': [1, 3, 5, 7]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=3)

# %%
grid_search_cv.best_params_
# Out:
# {'colsample_bytree': 0.4,
#  'gamma': 0.1,
#  'learning_rate': 0.3,
#  'max_depth': 10,
#  'min_child_weight': 1}

# %%
xgb1=XGBRegressor(colsample_bytree=0.4,gamma= 0.1, learning_rate= 0.3, max_depth= 10, min_child_weight= 1)

# %%
xgb1.fit(X_train,y_train)
# Out:
# [09:48:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0.1,
#              importance_type='gain', learning_rate=0.3, max_delta_step=0,
#              max_depth=10, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
predict1 = xgb1.predict(X_test)

# %%
xgb1.score(X_train, y_train)
# Out:
# 0.8369657017125061

# %%
xgb1.score(X_test, y_test)
# Out:
# 0.8233490234553964
